# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Shelter Outcomes
# We are given a dataset from the Austin Animal Center with pet intake information. The goal is to predict the outcome for each animal to help the shelter identify which specific animals could use extra focus to help ensure a positive outcome.

# %% [markdown]
# Let's first read in the datasets and combine into a single DataFrame

# %%
train = pd.read_csv('train.csv')
train.drop('AnimalID', inplace=True, axis=1)
test = pd.read_csv('test.csv')
test.drop('ID', inplace=True, axis=1)
df = pd.concat([train, test], ignore_index=True)
df.head()
# Out:
#   AgeuponOutcome AnimalType                        Breed        Color  \
# 0         1 year        Dog        Shetland Sheepdog Mix  Brown/White
# 1         1 year        Cat       Domestic Shorthair Mix  Cream Tabby
# 2        2 years        Dog                 Pit Bull Mix   Blue/White
# 3        3 weeks        Cat       Domestic Shorthair Mix   Blue Cream
# 4        2 years        Dog  Lhasa Apso/Miniature Poodle          Tan
#
#               DateTime     Name OutcomeSubtype      OutcomeType SexuponOutcome
# 0  2014-02-12 18:22:00  Hambone            NaN  Return_to_owner  Neutered Male
# 1  2013-10-13 12:44:00    Emily      Suffering       Euthanasia  Spayed Female
# 2  2015-01-31 12:28:00   Pearce         Foster         Adoption  Neutered Male
# 3  2014-07-11 19:09:00      NaN        Partner         Transfer    Intact Male
# 4  2013-11-15 12:52:00      NaN        Partner         Transfer  Neutered Male

# %% [markdown]
# ## Seasonal Trends
# Grouping by month, we can see that there is a strong trend in the cat population but very little in the dog population. It seems that the total number of animals greatly increases in the summer months for cats.

# %%
df['DateTime'] = pd.to_datetime(df['DateTime'])
df['YearMonth'] = df['DateTime'].dt.strftime('%Y-%m')

# %%
df.groupby(['YearMonth', 'AnimalType']).size().unstack().plot(kind='bar')

# %% [markdown]
# Let's look further and see what type of outcomes these were for each animal type.

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,5))
for ax, animal in zip(axs, df['AnimalType'].unique()):
    df[df['AnimalType']==animal].groupby(['YearMonth', 'OutcomeType']).size().unstack().plot(kind='line', ax=ax, 
                                                                                             title=animal, legend=False)
axs[0].legend(loc='center left', bbox_to_anchor=(0.3, -.2), ncol=5)

# %% [markdown]
# We see no real trends for dogs, but see that in the summer adoptions and transfers spiked for cats.

# %% [markdown]
# ## Animal Age
# To pull out animal age, we need to process the strings given in AgeUponOutcome. Since ages are only given using a single term in the list of week, month, week and day, we will unfortunately have different resolutions across our range.

# %%
def yearFromString(s):
    if pd.isnull(s): return s
    words = s.split()
    scale = 0
    if 'year' in words[1]:
        scale = 1
    elif 'month' in words[1]:
        scale = 12
    elif 'week' in words[1]:
        scale = 52
    elif 'day' in words[1]:
        scale = 365
    return float(words[0])/scale
df['Age'] = df['AgeuponOutcome'].apply(yearFromString)

# %%
df.hist(column='Age', by='AnimalType', bins=30, sharey=True, sharex=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x113b89a20>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x10ca4d400>], dtype=object)

# %%
df.boxplot(column='Age', by='OutcomeType', rot=90)

# %% [markdown]
# # Color
# Let's start by looking at the number of unique values.

# %%
df['Color'][0:30]
# Out:
# 0             Brown/White
# 1             Cream Tabby
# 2              Blue/White
# 3              Blue Cream
# 4                     Tan
# 5               Black/Tan
# 6              Blue Tabby
# 7             Brown Tabby
# 8               Red/White
# 9                   White
# 10                  Black
# 11                 Silver
# 12                  Brown
# 13              Black/Red
# 14            White/Cream
# 15     Orange Tabby/White
# 16            Brown Tabby
# 17            Brown/White
# 18                  White
# 19                  Black
# 20            Black/White
# 21                  White
# 22    Brown Brindle/White
# 23            Brown/White
# 24            Black/Brown
# 25           Orange Tabby
# 26        Chocolate/White
# 27              White/Tan
# 28      Cream Tabby/White
# 29                   Blue
# Name: Color, dtype: object

# %%
# ColorList = df['Color'].str.split('[\s/]', expand=True)
# df['Color'].str.split('[\s/]', expand=True).columns
# pd.get_dummies(ColorList, columns=ColorList.columns, sparse=True)

ColorDummies = df['Color'].str.get_dummies('/')
# df = pd.concat([df, ColorDummies])

# %%
TopColors = ColorDummies.sum().sort_values(ascending=False)[0:10].index.values

# %%
df.head()
# Out:
#   AgeuponOutcome AnimalType                        Breed        Color  \
# 0         1 year        Dog        Shetland Sheepdog Mix  Brown/White
# 1         1 year        Cat       Domestic Shorthair Mix  Cream Tabby
# 2        2 years        Dog                 Pit Bull Mix   Blue/White
# 3        3 weeks        Cat       Domestic Shorthair Mix   Blue Cream
# 4        2 years        Dog  Lhasa Apso/Miniature Poodle          Tan
#
#              DateTime     Name OutcomeSubtype      OutcomeType SexuponOutcome  \
# 0 2014-02-12 18:22:00  Hambone            NaN  Return_to_owner  Neutered Male
# 1 2013-10-13 12:44:00    Emily      Suffering       Euthanasia  Spayed Female
# 2 2015-01-31 12:28:00   Pearce         Foster         Adoption  Neutered Male
# 3 2014-07-11 19:09:00      NaN        Partner         Transfer    Intact Male
# 4 2013-11-15 12:52:00      NaN        Partner         Transfer  Neutered Male
#
#   YearMonth       Age
# 0   2014-02  1.000000
# 1   2013-10  1.000000
# 2   2015-01  2.000000
# 3   2014-07  0.057692
# 4   2013-11  2.000000

# %%
df['OutcomePositive'] = df['OutcomeType'].map({'Adoption': True, 'Died': False, 'Euthanasia':False, 
                                               'Return_to_owner': True, 'Transfer': True})

# %%
df.ix[ColorDummies.groupby('White').groups[1]].groupby('OutcomeType').size()
# Out:
# OutcomeType
# Adoption           5013
# Died                 89
# Euthanasia          736
# Return_to_owner    2397
# Transfer           3951
# dtype: int64

# %%
AdoptionPerc = []
for c in TopColors:
    cgroup = df.ix[ColorDummies.groupby(c).groups[1]].groupby('OutcomeType').size()
    AdoptionPerc.append(cgroup['Transfer'] / cgroup.sum())
Series(AdoptionPerc, index=TopColors).plot(kind='bar')
