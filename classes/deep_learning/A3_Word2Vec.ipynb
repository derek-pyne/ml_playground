# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import collections
import math
import os
import random
import sys
from tempfile import gettempdir
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

from tensorflow.contrib.tensorboard.plugins import projector

# %% [markdown]
# # Word2Vec with Tensorflow
# Author: Derek Pyne

# %% [markdown]
# Read the TensorFlow word2vec tutorial at https://www.tensorflow.org/tutorials/representation/word2vec (Links to an external site.)Links to an external site.
#
# Copy the code from https://github.com/tensorflow/tensorflow/blob/master/tensorflow/examples/tutorials/word2vec/word2vec_basic.py (Links to an external site.)Links to an external site. into a Colab notebook and run it.
#
# #### Question 1: Increase the skip window.  Looking at the training error and the closest words, does the model seem to get better or worse? Explain why. (3 marks)
#
# Increasing the `skip_window` from 1 to 3 increased the training error by 9% during the final step (from 4.7 to 5.1). However, both models still seem only partially appropriate when looking at the closest words.
#
# For instance, both models seem to have grouped numbers together:
#
# **Base Model**
# `Nearest to five: four, three, six, seven, eight, two, nine, zero,`
#
# **Larger Skip Window**
# `Nearest to three: four, five, six, seven, eight, two, zero, nine,`
#
# Yet still struggle with more complicated concepts:
#
# **Base Model**
# `Nearest to people: buckner, showtime, men, circ, apc, gb, cebus, anchors,`
#
# **Larger Skip Window**
# `Nearest to people: and, zero, abet, agouti, aveiro, concerned, their, circ,`
#
# It is difficult to judge here if either model is better or worse.
#
# A larger `skip_window` should allow the model to learn more complicated relationship. However, adding this increase capability to the model will require longer training times so that more data can be run through the model (it will take longer to converge). In this case, the larger `skip_window` model was likely not trained for long enough to see if it will eventually plateau at a lower error then the base model.
#
# #### Question 2: Research and explain NCE loss. (3 marks)
#
# A traditional neural probabilistic model would be trained using the maximum likelihood principle. This would involve predicting a probability for each word in the vocabulary and normalizing the distribution with a softmax function. However, for a large vocabulary, this becomes extremely computationally expensive.
#
# Noise contrastive estimation lowers the computational requirements by transforming this multi-class classification into a binary classification. NCE changes the optimization from trying to predict the next word in a sequence, to instead classifying whether a given pair of words are good or bad together. It does this by using pairs of words found in the same context as positive examples, and by fabricating pairs using noise words as negative examples. The model is then trained to differentiate these noise examples from the true context pair examples.
#
# #### Question 3: Why replace rare words with UNK rather than keeping them? (2 marks)
#
# Rare words are replaced with a common symbol to lower the size of our vocabulary. This is essentially cutting of the long tail of our word distribution and grouping these words together in a single symbol.
#
# A lower vocabulary will help decrease training time and stop the model from attempting to fit rare words. This is good since there is too little data for these rare words for us to reasonable expect our model to build an understanding of them.
#
# #### Question 4: If you run the model more than once the t-SNE plot looks different each time.  Why? (2 marks)
#
# t-SNE is a stochastic approach and will thus produce a different result everytime it is ran. The goal of t-SNE is to transform a higher dimensional space into a 2 or 3 dimensional space where observations in this lower dimensional space are clustered by their proximity in the higher dimensional spaces. In other words, more similar observations will be closer together in the t-SNE plot, but it is random where they will exactly be located.
#
# #### Question 5: What happens to accuracy if you set vocabulary_size to 500?  Explain why. (3 marks)
#
# Decreasing the vocabulary size to 500 lowered the training error by 24% (from 4.7 to 3.6). We can also see it start to understand some more complicated concepts:
#
# `Nearest to states: countries, UNK, european, members, council, modern, others, church,`
#
# Lowering the vocabulary size decreases the capability of the model. Since in this example setup we are only training our model for a limited amount of time, with a limited dataset, this lower capability model is able to converge much quicker. With more data and training time we would expect this model to plateau at a higher error then our other models.
#
# #### Question 6: You may see antonyms like “less” and “more” next to each other in the t-SNE.  How does that make sense rather than them being at opposite ends of the plot? (2 marks)
# Our Word2Vec model is built around the hypothesis that words that appear in similar contexts have similar meanings. From this point of view, 'less' and 'more' are very similar in many ways: they are used to compare two things, and they can both be used as pronouns or adverbs. The concept of opposites is then completely lost on the Word2Vec model. This concept which us humans can easily pull apart, completely confuses the model.
#
# Given this limitation, seeing antonyms close together in our Word2Vec model, given its assumptions, is actually a good indicator that it is training well.

# %%
data_index = 0


def word2vec_basic(log_dir):
  """Example of building, training and visualizing a word2vec model."""
  # Create the directory for TensorBoard variables if there is not.
  if not os.path.exists(log_dir):
    os.makedirs(log_dir)

  # Step 1: Download the data.
  url = 'http://mattmahoney.net/dc/'

  # pylint: disable=redefined-outer-name
  def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    local_filename = os.path.join(gettempdir(), filename)
    if not os.path.exists(local_filename):
      local_filename, _ = urllib.request.urlretrieve(url + filename,
                                                     local_filename)
    statinfo = os.stat(local_filename)
    if statinfo.st_size == expected_bytes:
      print('Found and verified', filename)
    else:
      print(statinfo.st_size)
      raise Exception('Failed to verify ' + local_filename +
                      '. Can you get to it with a browser?')
    return local_filename

  filename = maybe_download('text8.zip', 31344016)

  # Read the data into a list of strings.
  def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words."""
    with zipfile.ZipFile(filename) as f:
      data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

  vocabulary = read_data(filename)
  print('Data size', len(vocabulary))

  # Step 2: Build the dictionary and replace rare words with UNK token.
#   vocabulary_size = 50000

  def build_dataset(words, n_words):
    """Process raw inputs into a dataset."""
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
      dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
      index = dictionary.get(word, 0)
      if index == 0:  # dictionary['UNK']
        unk_count += 1
      data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary

  # Filling 4 global variables:
  # data - list of codes (integers from 0 to vocabulary_size-1).
  #   This is the original text but words are replaced by their codes
  # count - map of words(strings) to count of occurrences
  # dictionary - map of words(strings) to their codes(integers)
  # reverse_dictionary - maps codes(integers) to words(strings)
  data, count, unused_dictionary, reverse_dictionary = build_dataset(
      vocabulary, vocabulary_size)
  del vocabulary  # Hint to reduce memory.
  print('Most common words (+UNK)', count[:5])
  print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])

  # Step 3: Function to generate a training batch for the skip-gram model.
  def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1  # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)  # pylint: disable=redefined-builtin
    if data_index + span > len(data):
      data_index = 0
    buffer.extend(data[data_index:data_index + span])
    data_index += span
    for i in range(batch_size // num_skips):
      context_words = [w for w in range(span) if w != skip_window]
      words_to_use = random.sample(context_words, num_skips)
      for j, context_word in enumerate(words_to_use):
        batch[i * num_skips + j] = buffer[skip_window]
        labels[i * num_skips + j, 0] = buffer[context_word]
      if data_index == len(data):
        buffer.extend(data[0:span])
        data_index = span
      else:
        buffer.append(data[data_index])
        data_index += 1
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels

  batch, labels = generate_batch(batch_size=8, num_skips=2, skip_window=1)
  for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0],
          reverse_dictionary[labels[i, 0]])

  # Step 4: Build and train a skip-gram model.

#   batch_size = 128
#   embedding_size = 128  # Dimension of the embedding vector.
#   skip_window = 1  # How many words to consider left and right.
#   num_skips = 2  # How many times to reuse an input to generate a label.
#   num_sampled = 64  # Number of negative examples to sample.

  # We pick a random validation set to sample nearest neighbors. Here we limit
  # the validation samples to the words that have a low numeric ID, which by
  # construction are also the most frequent. These 3 variables are used only for
  # displaying model accuracy, they don't affect calculation.
  valid_size = 16  # Random set of words to evaluate similarity on.
  valid_window = 100  # Only pick dev samples in the head of the distribution.
  valid_examples = np.random.choice(valid_window, valid_size, replace=False)

  graph = tf.Graph()

  with graph.as_default():

    # Input data.
    with tf.name_scope('inputs'):
      train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
      train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
      valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
      # Look up embeddings for inputs.
      with tf.name_scope('embeddings'):
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        embed = tf.nn.embedding_lookup(embeddings, train_inputs)

      # Construct the variables for the NCE loss
      with tf.name_scope('weights'):
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size],
                                stddev=1.0 / math.sqrt(embedding_size)))
      with tf.name_scope('biases'):
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Compute the average NCE loss for the batch.
    # tf.nce_loss automatically draws a new sample of the negative labels each
    # time we evaluate the loss.
    # Explanation of the meaning of NCE loss:
    #   http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/
    with tf.name_scope('loss'):
      loss = tf.reduce_mean(
          tf.nn.nce_loss(
              weights=nce_weights,
              biases=nce_biases,
              labels=train_labels,
              inputs=embed,
              num_sampled=num_sampled,
              num_classes=vocabulary_size))

    # Add the loss value as a scalar to summary.
    tf.summary.scalar('loss', loss)

    # Construct the SGD optimizer using a learning rate of 1.0.
    with tf.name_scope('optimizer'):
      optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)

    # Compute the cosine similarity between minibatch examples and all
    # embeddings.
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings,
                                              valid_dataset)
    similarity = tf.matmul(
        valid_embeddings, normalized_embeddings, transpose_b=True)

    # Merge all summaries.
    merged = tf.summary.merge_all()

    # Add variable initializer.
    init = tf.global_variables_initializer()

    # Create a saver.
    saver = tf.train.Saver()

  # Step 5: Begin training.
  num_steps = 100001

  with tf.Session(graph=graph) as session:
    # Open a writer to write summaries.
    writer = tf.summary.FileWriter(log_dir, session.graph)

    # We must initialize all variables before we use them.
    init.run()
    print('Initialized')

    average_loss = 0
    for step in xrange(num_steps):
      batch_inputs, batch_labels = generate_batch(batch_size, num_skips,
                                                  skip_window)
      feed_dict = {train_inputs: batch_inputs, train_labels: batch_labels}

      # Define metadata variable.
      run_metadata = tf.RunMetadata()

      # We perform one update step by evaluating the optimizer op (including it
      # in the list of returned values for session.run()
      # Also, evaluate the merged op to get all summaries from the returned
      # "summary" variable. Feed metadata variable to session for visualizing
      # the graph in TensorBoard.
      _, summary, loss_val = session.run([optimizer, merged, loss],
                                         feed_dict=feed_dict,
                                         run_metadata=run_metadata)
      average_loss += loss_val

      # Add returned summaries to writer in each step.
      writer.add_summary(summary, step)
      # Add metadata to visualize the graph for the last run.
      if step == (num_steps - 1):
        writer.add_run_metadata(run_metadata, 'step%d' % step)

      if step % 2000 == 0:
        if step > 0:
          average_loss /= 2000
        # The average loss is an estimate of the loss over the last 2000
        # batches.
        print('Average loss at step ', step, ': ', average_loss)
        average_loss = 0

      # Note that this is expensive (~20% slowdown if computed every 500 steps)
      if step % 10000 == 0:
        sim = similarity.eval()
        for i in xrange(valid_size):
          valid_word = reverse_dictionary[valid_examples[i]]
          top_k = 8  # number of nearest neighbors
          nearest = (-sim[i, :]).argsort()[1:top_k + 1]
          log_str = 'Nearest to %s:' % valid_word
          for k in xrange(top_k):
            close_word = reverse_dictionary[nearest[k]]
            log_str = '%s %s,' % (log_str, close_word)
          print(log_str)
    final_embeddings = normalized_embeddings.eval()

    # Write corresponding labels for the embeddings.
    with open(log_dir + '/metadata.tsv', 'w') as f:
      for i in xrange(vocabulary_size):
        f.write(reverse_dictionary[i] + '\n')

    # Save the model for checkpoints.
    saver.save(session, os.path.join(log_dir, 'model.ckpt'))

    # Create a configuration for visualizing embeddings with the labels in
    # TensorBoard.
    config = projector.ProjectorConfig()
    embedding_conf = config.embeddings.add()
    embedding_conf.tensor_name = embeddings.name
    embedding_conf.metadata_path = os.path.join(log_dir, 'metadata.tsv')
    projector.visualize_embeddings(writer, config)

  writer.close()

  # Step 6: Visualize the embeddings.

  # pylint: disable=missing-docstring
  # Function to draw visualization of distance between embeddings.
  def plot_with_labels(low_dim_embs, labels, filename):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
      x, y = low_dim_embs[i, :]
      plt.scatter(x, y)
      plt.annotate(
          label,
          xy=(x, y),
          xytext=(5, 2),
          textcoords='offset points',
          ha='right',
          va='bottom')

    plt.savefig(filename)

  try:
    # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt

    tsne = TSNE(
        perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels, os.path.join(gettempdir(),
                                                        'tsne.png'))

  except ImportError as ex:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
    print(ex)


# All functionality is run after tf.app.run() (b/122547914). This could be split
# up but the methods are laid sequentially with their usage for clarity.
def main():
  # Give a folder path as an argument with '--log_dir' to save
  # TensorBoard summaries. Default is a log folder in current directory.
  current_path = os.path.dirname(os.path.realpath(sys.argv[0]))

  parser = argparse.ArgumentParser()
  parser.add_argument(
      '--log_dir',
      type=str,
      default=os.path.join(current_path, 'log'),
      help='The log directory for TensorBoard summaries.')
  flags, unused_flags = parser.parse_known_args()
  word2vec_basic(flags.log_dir)

# %%
# Base output
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.
vocabulary_size = 50000
main()
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 5234 anarchism
# 3081 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 2 of
# 195 term -> 6 a
# Initialized
# Average loss at step  0 :  262.788330078125
# Nearest to have: compliment, poset, nicaragua, cirrhosis, rearranging, intermixed, tailpiece, captors,
# Nearest to has: rms, commando, commercially, workman, biology, presbyterianism, radbruch, peacemaker,
# Nearest to can: gladiator, uu, gchq, purports, impervious, ferromagnetic, privately, extrinsic,
# Nearest to most: gigue, ansbach, fenian, baptise, embalmed, deterioration, annihilated, kennedy,
# Nearest to see: buridan, pinter, circumcised, thulsa, surveillance, bribery, gillette, affectionate,
# Nearest to b: everyday, lderlin, trick, labs, neutrinos, rather, weinberg, guilty,
# Nearest to or: tleilaxu, sends, planks, holiness, latinos, romantic, divinely, tribunes,
# Nearest to if: hp, stanis, edelman, moss, switzerland, infidel, meager, average,
# Nearest to this: ivies, til, ridiculed, digs, shaky, sammy, extraneous, signage,
# Nearest to people: showtime, osce, decomposed, stills, gime, yemenite, sulfides, apc,
# Nearest to UNK: stacy, norwegians, accounts, allusions, brian, switches, acceptance, sayyaf,
# Nearest to one: knocked, sal, mutagenic, explosive, murchison, mackaye, amo, danny,
# Nearest to five: musik, berb, corresponds, barbaric, warmest, poppy, christological, extracts,
# Nearest to system: preparations, terra, censorial, sahih, semiconducting, dentists, khayyam, necropolis,
# Nearest to up: calvinball, voucher, lightsaber, standings, classically, kinetochore, postalveolar, marguerite,
# Nearest to with: consummate, discreetly, ashamed, misled, azhar, requiem, graduate, stabilize,
# Average loss at step  2000 :  113.21754455661774
# Average loss at step  4000 :  52.99722084951401
# Average loss at step  6000 :  33.10957689070702
# Average loss at step  8000 :  23.61379705166817
# Average loss at step  10000 :  18.198293276906014
# Nearest to have: has, is, nicaragua, was, basins, like, advocated, altenberg,
# Nearest to has: is, rms, mp, have, mall, merchant, gardening, inherently,
# Nearest to can: is, gb, purports, hearts, nobility, striking, distance, founder,
# Nearest to most: kennedy, one, projects, ability, cana, honour, sparkling, quit,
# Nearest to see: gb, decreased, mathbf, usa, react, unstable, surveillance, falcon,
# Nearest to b: everyday, trick, aberdeen, infant, hor, rather, revered, hoare,
# Nearest to or: and, poverty, of, gb, romantic, antimatter, medicine, zero,
# Nearest to if: switzerland, frame, celebration, derives, die, basins, infidel, commands,
# Nearest to this: a, var, trench, ridiculed, individualist, resting, which, scrutiny,
# Nearest to people: adopted, gb, open, amundsen, scratch, pago, fao, period,
# Nearest to UNK: one, and, gb, altenberg, mosque, ada, boards, milne,
# Nearest to one: two, fao, nine, UNK, zero, altenberg, archie, basins,
# Nearest to five: nine, zero, four, archie, fao, altenberg, speakers, eight,
# Nearest to system: preparations, demanded, leakey, terra, tubing, selection, choose, undergone,
# Nearest to up: aries, classically, tournaments, theologian, ball, sister, apollon, winnie,
# Nearest to with: in, by, and, graduate, omotic, of, gb, dos,
# Average loss at step  12000 :  13.95878670322895
# Average loss at step  14000 :  11.528920606136323
# Average loss at step  16000 :  9.964462852478027
# Average loss at step  18000 :  8.55299581837654
# Average loss at step  20000 :  7.979011863231659
# Nearest to have: has, had, be, was, are, agarose, nicaragua, sq,
# Nearest to has: is, had, have, was, rms, but, mp, merchant,
# Nearest to can: frying, is, to, purports, gladiator, gb, hearts, alike,
# Nearest to most: ansbach, kennedy, antiprism, incarnation, astrophysicist, arian, operatorname, agouti,
# Nearest to see: gb, decreased, react, mathbf, visigoths, falcon, launches, eu,
# Nearest to b: d, and, trick, circ, infant, everyday, agouti, revered,
# Nearest to or: and, operatorname, zero, dasyprocta, synthesize, hydrophilic, gb, s,
# Nearest to if: switzerland, celebration, hydrophilic, frame, derives, die, stanis, agouti,
# Nearest to this: the, a, which, it, var, and, scrutiny, its,
# Nearest to people: gb, circ, dasyprocta, adopted, UNK, showtime, amundsen, wavelength,
# Nearest to UNK: dasyprocta, operatorname, circ, gb, agouti, two, three, milne,
# Nearest to one: two, operatorname, three, agouti, eight, four, nine, six,
# Nearest to five: nine, zero, four, eight, seven, two, three, six,
# Nearest to system: preparations, elgin, demanded, leakey, tubing, UNK, programmers, terra,
# Nearest to up: classically, townsend, theologian, aries, gollancz, tournaments, apollon, sister,
# Nearest to with: in, by, and, for, operatorname, of, as, omotic,
# Average loss at step  22000 :  7.158477253317833
# Average loss at step  24000 :  6.855301512241364
# Average loss at step  26000 :  6.719922083377838
# Average loss at step  28000 :  6.373494588136673
# Average loss at step  30000 :  5.874289736747742
# Nearest to have: had, has, be, are, were, include, sq, agarose,
# Nearest to has: had, is, have, was, but, rms, gladiator, merchant,
# Nearest to can: to, will, would, could, may, must, frying, should,
# Nearest to most: ansbach, kennedy, incarnation, antiprism, astrophysicist, arian, entebbe, sparkling,
# Nearest to see: gb, decreased, circumcised, react, has, mathbf, gib, omari,
# Nearest to b: d, primigenius, and, revered, trick, infant, condorcet, circ,
# Nearest to or: and, operatorname, dasyprocta, abet, one, sponsors, five, agave,
# Nearest to if: but, abet, celebration, frame, stanis, hydrophilic, derives, switzerland,
# Nearest to this: which, the, it, a, var, operatorname, its, scrutiny,
# Nearest to people: UNK, gb, apc, circ, adopted, dasyprocta, amundsen, showtime,
# Nearest to UNK: dasyprocta, gb, operatorname, agouti, circ, two, four, five,
# Nearest to one: two, four, three, seven, operatorname, eight, agouti, circ,
# Nearest to five: four, eight, seven, six, nine, zero, three, circ,
# Nearest to system: preparations, leakey, elgin, which, tubing, demanded, programmers, terra,
# Nearest to up: classically, townsend, aries, gollancz, observance, theologian, apollon, tournaments,
# Nearest to with: in, by, for, operatorname, and, as, seven, omotic,
# Average loss at step  32000 :  5.93676692044735
# Average loss at step  34000 :  5.6879381337165835
# Average loss at step  36000 :  5.7276846994161605
# Average loss at step  38000 :  5.484207410931587
# Average loss at step  40000 :  5.264278308749199
# Nearest to have: has, had, be, are, were, include, make, like,
# Nearest to has: had, have, was, is, but, zero, reddy, gladiator,
# Nearest to can: will, may, would, could, must, should, to, frying,
# Nearest to most: ansbach, incarnation, antiprism, kennedy, operatorname, ability, sparkling, avowed,
# Nearest to see: gb, circumcised, has, omari, decreased, zero, mathbf, gib,
# Nearest to b: d, UNK, primigenius, circ, chairmen, trick, agouti, hoare,
# Nearest to or: and, zero, operatorname, dasyprocta, including, abet, vma, sponsors,
# Nearest to if: but, abet, celebration, derives, stanis, hydrophilic, frame, because,
# Nearest to this: which, the, it, that, a, var, zero, its,
# Nearest to people: apc, gb, circ, zero, amundsen, scratch, tasks, wishes,
# Nearest to UNK: dasyprocta, gb, operatorname, zero, four, agouti, circ, three,
# Nearest to one: two, four, three, operatorname, six, five, seven, eight,
# Nearest to five: four, seven, three, six, eight, zero, nine, two,
# Nearest to system: preparations, tubing, elgin, which, programmers, leakey, demanded, albury,
# Nearest to up: classically, townsend, aries, observance, jude, gollancz, cv, obliged,
# Nearest to with: operatorname, and, by, for, zero, in, omotic, kifl,
# Average loss at step  42000 :  5.360291640758515
# Average loss at step  44000 :  5.242224060058594
# Average loss at step  46000 :  5.230648798704148
# Average loss at step  48000 :  5.2294598581790925
# Average loss at step  50000 :  4.9874192636013035
# Nearest to have: had, has, be, are, were, make, sq, like,
# Nearest to has: had, was, have, is, but, reddy, weir, dissension,
# Nearest to can: will, may, would, could, must, should, to, frying,
# Nearest to most: ansbach, antiprism, incarnation, ability, sparkling, kennedy, operatorname, buttons,
# Nearest to see: gb, circumcised, omari, ke, decreased, gib, biostatistics, gillette,
# Nearest to b: d, circ, primigenius, agouti, chairmen, hoare, kapoor, condorcet,
# Nearest to or: and, operatorname, dasyprocta, than, five, mukherjee, four, two,
# Nearest to if: but, abet, hydrophilic, when, because, agouti, for, neither,
# Nearest to this: which, it, the, that, a, var, operatorname, one,
# Nearest to people: buckner, UNK, apc, gb, circ, ha, amundsen, tasks,
# Nearest to UNK: dasyprocta, mukherjee, kapoor, gb, circ, operatorname, agouti, five,
# Nearest to one: two, four, three, five, six, eight, operatorname, seven,
# Nearest to five: four, six, seven, three, eight, two, zero, kapoor,
# Nearest to system: preparations, pairings, tubing, elgin, which, assertion, demanded, programmers,
# Nearest to up: classically, townsend, cv, aries, observance, obliged, jude, apology,
# Nearest to with: for, by, operatorname, and, in, omotic, or, gb,
# Average loss at step  52000 :  5.054633981227875
# Average loss at step  54000 :  5.1822996773719785
# Average loss at step  56000 :  5.054624698758126
# Average loss at step  58000 :  5.063381876587868
# Average loss at step  60000 :  4.946300349712372
# Nearest to have: had, has, were, are, be, make, include, like,
# Nearest to has: had, have, was, is, but, weir, dissension, reddy,
# Nearest to can: would, may, will, could, should, must, to, cannot,
# Nearest to most: ansbach, balboa, antiprism, incarnation, ursus, ability, operatorname, benefit,
# Nearest to see: gb, nul, circumcised, microbats, ke, but, six, gib,
# Nearest to b: d, primigenius, circ, revealing, hoare, turbulent, chairmen, revered,
# Nearest to or: and, ursus, operatorname, dasyprocta, mukherjee, but, than, five,
# Nearest to if: but, when, abet, because, hydrophilic, is, agouti, neither,
# Nearest to this: which, it, the, that, one, ursus, var, agouti,
# Nearest to people: buckner, showtime, circ, gb, apc, ha, amundsen, tasks,
# Nearest to UNK: dasyprocta, kapoor, ursus, mukherjee, gb, operatorname, pulau, agouti,
# Nearest to one: four, two, six, three, five, eight, seven, ursus,
# Nearest to five: four, six, eight, three, seven, nine, ursus, zero,
# Nearest to system: preparations, pairings, pulau, tubing, assertion, asimov, ursus, demanded,
# Nearest to up: classically, obliged, townsend, cv, observance, apology, bethel, jude,
# Nearest to with: operatorname, in, and, by, for, omotic, gb, slug,
# Average loss at step  62000 :  5.02530646944046
# Average loss at step  64000 :  4.837890552222729
# Average loss at step  66000 :  4.612326174020767
# Average loss at step  68000 :  4.9769445798397065
# Average loss at step  70000 :  4.887056763291359
# Nearest to have: had, has, were, are, be, make, include, establish,
# Nearest to has: had, have, was, is, cebus, but, callithrix, although,
# Nearest to can: may, will, would, could, should, must, cannot, microbats,
# Nearest to most: ansbach, many, antiprism, balboa, ability, incarnation, operatorname, more,
# Nearest to see: gb, nul, microbats, circumcised, but, ke, decreased, gib,
# Nearest to b: d, UNK, circ, clo, seven, primigenius, mico, turbulent,
# Nearest to or: and, upanija, mico, ursus, operatorname, but, dasyprocta, microcebus,
# Nearest to if: but, when, because, cebus, abet, though, where, hydrophilic,
# Nearest to this: which, it, the, that, scrutiny, callithrix, var, ursus,
# Nearest to people: buckner, circ, apc, gb, showtime, cebus, ha, amundsen,
# Nearest to UNK: dasyprocta, ursus, kapoor, mukherjee, circ, microcebus, gb, operatorname,
# Nearest to one: four, two, six, three, five, eight, seven, ursus,
# Nearest to five: four, six, three, eight, seven, nine, zero, two,
# Nearest to system: preparations, semiconducting, assertion, callithrix, pairings, tubing, asimov, pulau,
# Nearest to up: classically, them, obliged, townsend, cv, observance, bethel, apology,
# Nearest to with: operatorname, omotic, by, between, and, for, gb, in,
# Average loss at step  72000 :  4.758012343764305
# Average loss at step  74000 :  4.811439550757408
# Average loss at step  76000 :  4.712574292778969
# Average loss at step  78000 :  4.789993296325207
# Average loss at step  80000 :  4.786214892745018
# Nearest to have: had, has, were, are, be, include, establish, like,
# Nearest to has: had, have, was, is, cebus, although, dissension, weir,
# Nearest to can: may, would, will, could, should, must, cannot, to,
# Nearest to most: many, some, more, antiprism, ansbach, operatorname, balboa, ursus,
# Nearest to see: gb, nul, microbats, but, ke, circumcised, gib, callithrix,
# Nearest to b: d, UNK, circ, clo, primigenius, agouti, mico, microcebus,
# Nearest to or: and, upanija, ursus, operatorname, mico, than, dasyprocta, abet,
# Nearest to if: when, but, because, where, cebus, neither, though, agouti,
# Nearest to this: which, it, that, the, callithrix, another, some, agouti,
# Nearest to people: buckner, showtime, apc, gb, circ, ha, men, amundsen,
# Nearest to UNK: dasyprocta, ursus, kapoor, callithrix, mukherjee, gb, microcebus, operatorname,
# Nearest to one: two, seven, three, six, four, five, ursus, operatorname,
# Nearest to five: four, six, seven, eight, three, nine, two, zero,
# Nearest to system: preparations, semiconducting, assertion, pairings, tubing, callithrix, asimov, lett,
# Nearest to up: classically, them, obliged, bethel, cv, jude, townsend, adjoint,
# Nearest to with: operatorname, by, in, between, for, and, omotic, slug,
# Average loss at step  82000 :  4.762341557741165
# Average loss at step  84000 :  4.751287063002587
# Average loss at step  86000 :  4.766423602700233
# Average loss at step  88000 :  4.76032531940937
# Average loss at step  90000 :  4.71979231274128
# Nearest to have: had, has, were, are, be, include, according, establish,
# Nearest to has: had, have, was, is, although, cebus, but, callithrix,
# Nearest to can: may, will, would, could, should, must, cannot, might,
# Nearest to most: many, more, some, antiprism, ansbach, operatorname, ursus, balboa,
# Nearest to see: nul, gb, microbats, but, ke, circumcised, loci, callithrix,
# Nearest to b: d, UNK, clo, circ, primigenius, six, agouti, mico,
# Nearest to or: and, ursus, operatorname, upanija, than, four, mico, dasyprocta,
# Nearest to if: when, because, where, but, though, cebus, neither, scalia,
# Nearest to this: which, it, the, that, one, another, some, agouti,
# Nearest to people: buckner, apc, showtime, men, gb, circ, anchors, ha,
# Nearest to UNK: kapoor, ursus, dasyprocta, callithrix, operatorname, mukherjee, agouti, microcebus,
# Nearest to one: four, three, two, seven, eight, five, six, ursus,
# Nearest to five: four, seven, eight, six, three, zero, nine, two,
# Nearest to system: preparations, assertion, semiconducting, tubing, callithrix, lett, pairings, asimov,
# Nearest to up: them, classically, obliged, bethel, cv, jude, adjoint, townsend,
# Nearest to with: operatorname, between, by, in, omotic, for, slug, tangled,
# Average loss at step  92000 :  4.680829119563103
# Average loss at step  94000 :  4.744506018996239
# Average loss at step  96000 :  4.700195029139519
# Average loss at step  98000 :  4.591996248483658
# Average loss at step  100000 :  4.702722554445267
# Nearest to have: had, has, were, are, be, include, according, establish,
# Nearest to has: had, have, was, is, although, soc, callithrix, but,
# Nearest to can: may, could, will, would, should, must, cannot, might,
# Nearest to most: many, more, some, antiprism, operatorname, several, ansbach, ursus,
# Nearest to see: but, gb, microbats, nul, ke, callithrix, circumcised, pulau,
# Nearest to b: d, circ, clo, UNK, primigenius, agouti, mico, revealing,
# Nearest to or: and, upanija, ursus, operatorname, but, mico, than, dasyprocta,
# Nearest to if: when, because, where, though, but, cebus, agouti, although,
# Nearest to this: which, it, the, that, some, callithrix, ursus, agouti,
# Nearest to people: buckner, showtime, men, circ, apc, gb, cebus, anchors,
# Nearest to UNK: kapoor, dasyprocta, mukherjee, ursus, gb, microcebus, circ, callithrix,
# Nearest to one: six, four, two, five, seven, eight, three, ursus,
# Nearest to five: four, three, six, seven, eight, two, nine, zero,
# Nearest to system: preparations, assertion, semiconducting, tubing, albury, callithrix, systems, pairings,
# Nearest to up: them, obliged, classically, bethel, out, cv, into, jude,
# Nearest to with: between, operatorname, in, by, omotic, through, or, jati,

# %%
# Larger skip_window
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 3  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.
vocabulary_size = 50000
main()
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# 3081 originated -> 12 as
# 3081 originated -> 5234 anarchism
# 12 as -> 6 a
# 12 as -> 3081 originated
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of
# Initialized
# Average loss at step  0 :  277.6973876953125
# Nearest to which: argento, hangover, servius, clements, shakur, hata, wilkinson, definability,
# Nearest to has: dioscorus, neutralized, paragraph, clu, cd, twa, discharged, folk,
# Nearest to people: piece, cub, olwen, vanderbilt, mjf, dendrites, atrophy, coincided,
# Nearest to eight: slider, biochemist, drusus, marcelo, tertiary, frigg, clary, boeing,
# Nearest to the: decline, bronzes, grand, afrikaans, cmb, libertine, wrapped, leaky,
# Nearest to if: appletalk, mujahedeen, gardiner, aloysius, olomouc, incubation, barbecue, nico,
# Nearest to history: willamette, release, diarrhea, sacked, calderas, zed, carnivore, floresiensis,
# Nearest to been: tatars, christo, sunspots, secession, burgnich, bess, directness, maia,
# Nearest to three: conakry, daimyo, ganz, former, zeitschrift, din, karachi, pocketing,
# Nearest to these: mayhem, invertible, kindling, baptismal, fawcett, paganism, convent, nephite,
# Nearest to this: emmet, evatt, sergei, boardgamegeek, lancers, ariane, antiarrhythmic, lawless,
# Nearest to about: deism, unsuspecting, neolithic, proceeds, rescues, cookery, underbelly, popolo,
# Nearest to its: tit, inhabit, scholasticus, imax, jubilees, between, adaption, ivanhoe,
# Nearest to they: discernment, observers, undifferentiated, vanishes, scarce, pacifists, alzheimer, slaughter,
# Nearest to may: recanted, bushman, peculiarity, polisario, lakota, herein, ailes, yangon,
# Nearest to there: rest, sapkowski, solubility, twitching, cartridge, salvaged, thorpe, tang,
# Average loss at step  2000 :  112.74837958621978
# Average loss at step  4000 :  53.48706667137146
# Average loss at step  6000 :  33.715750334978104
# Average loss at step  8000 :  23.90054334592819
# Average loss at step  10000 :  18.681077221393586
# Nearest to which: UNK, or, and, archie, amsterdam, aberdeenshire, lieutenants, shakur,
# Nearest to has: is, extreme, cd, to, light, by, ulster, folk,
# Nearest to people: atrophy, piece, concerned, coke, zero, omega, omnibus, vehicles,
# Nearest to eight: phi, zero, rudolph, nine, during, six, archie, coke,
# Nearest to the: a, of, and, UNK, to, in, one, archie,
# Nearest to if: rebecca, christie, occur, aloysius, hms, conservatives, german, railhead,
# Nearest to history: release, diarrhea, fruit, reginae, altenberg, shield, across, commonwealth,
# Nearest to been: secession, maia, steve, agave, tatars, sunspots, surgery, vocals,
# Nearest to three: one, nine, zero, two, UNK, in, and, phi,
# Nearest to these: coke, fawcett, mayhem, installed, jo, hence, processor, storm,
# Nearest to this: UNK, in, looks, one, dot, sergei, fever, to,
# Nearest to about: deism, boroughs, southerners, advantage, methadone, leto, proceeds, phi,
# Nearest to its: between, debates, tit, inhabit, receiver, omega, relays, band,
# Nearest to they: observers, vanishes, and, to, UNK, yeast, mounting, intent,
# Nearest to may: differ, burgess, alpina, press, care, map, budget, escarpment,
# Nearest to there: moving, rest, cartridge, solubility, cdc, bhfiann, swiss, UNK,
# Average loss at step  12000 :  14.098707698345184
# Average loss at step  14000 :  12.192648426771164
# Average loss at step  16000 :  10.322669909000396
# Average loss at step  18000 :  8.760277849793434
# Average loss at step  20000 :  8.301952792406082
# Nearest to which: or, and, a, circ, that, in, of, the,
# Nearest to has: is, by, the, and, a, of, paragraph, ulster,
# Nearest to people: concerned, piece, atrophy, were, agouti, apatosaurus, lombardy, UNK,
# Nearest to eight: nine, zero, one, six, four, five, two, dasyprocta,
# Nearest to the: and, a, agouti, one, in, to, circ, UNK,
# Nearest to if: acapulco, hadith, agouti, intersecting, rebecca, disposition, proportional, christie,
# Nearest to history: diarrhea, release, agouti, shield, asic, jerry, the, mohammed,
# Nearest to been: a, was, tatars, circ, the, and, maia, dasyprocta,
# Nearest to three: zero, two, nine, one, five, seven, circ, eight,
# Nearest to these: circ, coke, fawcett, agouti, the, processor, mayhem, installed,
# Nearest to this: the, a, circ, and, it, to, that, in,
# Nearest to about: deism, three, circ, southerners, zero, boroughs, proceeds, advantage,
# Nearest to its: the, of, a, truetype, between, agouti, in, chariot,
# Nearest to they: and, to, circ, agouti, in, dasyprocta, is, vanishes,
# Nearest to may: alpina, differ, circ, burgess, lakota, peculiarity, press, care,
# Nearest to there: that, aslan, and, cartridge, moving, laboratories, rest, tenor,
# Average loss at step  22000 :  7.3493619952201845
# Average loss at step  24000 :  7.114295678138733
# Average loss at step  26000 :  7.0862701187133785
# Average loss at step  28000 :  6.789990195512772
# Average loss at step  30000 :  6.238291475296021
# Nearest to which: that, the, circ, and, a, or, by, to,
# Nearest to has: is, by, have, paragraph, to, as, a, and,
# Nearest to people: concerned, piece, were, atrophy, abet, agouti, zero, italiano,
# Nearest to eight: nine, four, six, five, three, seven, two, zero,
# Nearest to the: a, and, agouti, circ, in, s, dasyprocta, abet,
# Nearest to if: acapulco, hadith, agouti, intersecting, appletalk, proportional, in, can,
# Nearest to history: diarrhea, release, agouti, shield, abet, asic, walled, jerry,
# Nearest to been: tatars, circ, was, maia, have, a, dasyprocta, secession,
# Nearest to three: eight, two, five, seven, four, zero, six, nine,
# Nearest to these: circ, the, they, in, and, which, used, agouti,
# Nearest to this: a, the, it, that, circ, to, an, agouti,
# Nearest to about: deism, three, two, seven, circ, zero, southerners, proceeds,
# Nearest to its: the, truetype, a, agouti, of, between, an, and,
# Nearest to they: to, circ, with, and, agouti, these, dasyprocta, reuptake,
# Nearest to may: two, can, circ, alpina, differ, peculiarity, burgess, in,
# Nearest to there: that, aslan, cartridge, and, moving, circ, tenor, laboratories,
# Average loss at step  32000 :  6.296646782755852
# Average loss at step  34000 :  6.075475598573685
# Average loss at step  36000 :  6.097387743353844
# Average loss at step  38000 :  5.886224909186363
# Average loss at step  40000 :  5.648511371016502
# Nearest to which: that, and, circ, by, a, agouti, or, the,
# Nearest to has: is, by, have, had, paragraph, with, for, and,
# Nearest to people: zero, were, concerned, abet, agouti, piece, akita, the,
# Nearest to eight: six, seven, nine, three, four, five, zero, one,
# Nearest to the: a, circ, and, agouti, an, one, s, abet,
# Nearest to if: acapulco, hadith, agouti, can, proportional, that, abet, appletalk,
# Nearest to history: release, agouti, diarrhea, and, shield, abet, the, asic,
# Nearest to been: a, tatars, have, was, circ, maia, agave, dasyprocta,
# Nearest to three: five, six, eight, zero, two, four, seven, nine,
# Nearest to these: and, circ, they, which, the, agouti, coke, used,
# Nearest to this: it, the, a, that, an, circ, which, agouti,
# Nearest to about: deism, three, zero, two, four, southerners, circ, kifl,
# Nearest to its: the, a, truetype, agouti, an, of, between, with,
# Nearest to they: to, circ, these, agouti, and, it, with, dasyprocta,
# Nearest to may: can, circ, two, alpina, peculiarity, heh, zero, differ,
# Nearest to there: that, aslan, cartridge, in, moving, and, laboratories, tenor,
# Average loss at step  42000 :  5.757543401956558
# Average loss at step  44000 :  5.578169805288315
# Average loss at step  46000 :  5.571705631256103
# Average loss at step  48000 :  5.599232521057129
# Average loss at step  50000 :  5.367117040753365
# Nearest to which: that, circ, by, and, it, agouti, a, or,
# Nearest to has: have, is, had, by, was, and, paragraph, with,
# Nearest to people: and, were, abet, agouti, concerned, akita, circ, coke,
# Nearest to eight: seven, six, nine, three, four, five, one, two,
# Nearest to the: circ, agouti, s, and, a, abet, UNK, one,
# Nearest to if: acapulco, that, agouti, can, hadith, it, proportional, this,
# Nearest to history: in, agouti, abet, diarrhea, release, tyndall, circ, shield,
# Nearest to been: have, tatars, was, circ, maia, agave, secession, dasyprocta,
# Nearest to three: six, five, four, two, eight, seven, zero, one,
# Nearest to these: circ, they, in, which, and, are, agouti, for,
# Nearest to this: it, a, that, an, the, which, circ, for,
# Nearest to about: three, two, deism, southerners, circ, zero, five, kifl,
# Nearest to its: the, truetype, agouti, a, their, an, of, coke,
# Nearest to they: circ, it, these, agouti, and, dasyprocta, which, or,
# Nearest to may: can, circ, heh, two, alpina, qui, peculiarity, differ,
# Nearest to there: that, it, aslan, cartridge, not, and, in, these,
# Average loss at step  52000 :  5.418308534145355
# Average loss at step  54000 :  5.542525035738945
# Average loss at step  56000 :  5.441721700191498
# Average loss at step  58000 :  5.412837854146957
# Average loss at step  60000 :  5.347341919302941
# Nearest to which: that, circ, and, this, ursus, a, it, agouti,
# Nearest to has: have, had, is, by, was, and, ursus, with,
# Nearest to people: zero, and, were, abet, agouti, concerned, circ, their,
# Nearest to eight: seven, six, nine, four, five, three, two, zero,
# Nearest to the: a, ursus, agouti, circ, and, its, s, an,
# Nearest to if: that, acapulco, can, but, agouti, proportional, it, hadith,
# Nearest to history: agouti, ursus, abet, release, tyndall, and, circ, diarrhea,
# Nearest to been: have, was, tatars, be, were, circ, agave, dasyprocta,
# Nearest to three: six, five, four, two, seven, zero, eight, one,
# Nearest to these: circ, and, they, which, other, in, some, agouti,
# Nearest to this: it, a, which, that, an, the, circ, but,
# Nearest to about: three, two, deism, five, zero, circ, four, southerners,
# Nearest to its: the, their, a, agouti, truetype, ursus, an, and,
# Nearest to they: it, to, these, circ, agouti, that, he, but,
# Nearest to may: can, circ, but, heh, three, or, to, alpina,
# Nearest to there: that, it, not, which, however, circ, and, these,
# Average loss at step  62000 :  5.4077211644649505
# Average loss at step  64000 :  5.219974274158478
# Average loss at step  66000 :  5.051219315052032
# Average loss at step  68000 :  5.39357809972763
# Average loss at step  70000 :  5.273261653184891
# Nearest to which: that, circ, this, ursus, it, agouti, cebus, capuchin,
# Nearest to has: have, had, is, was, by, in, ursus, but,
# Nearest to people: concerned, agouti, abet, aveiro, coke, circ, inexplicably, apatosaurus,
# Nearest to eight: seven, six, four, five, nine, three, zero, two,
# Nearest to the: a, circ, ursus, agouti, an, this, callithrix, cebus,
# Nearest to if: that, but, acapulco, can, agouti, it, proportional, this,
# Nearest to history: agouti, ursus, abet, the, release, tyndall, see, circ,
# Nearest to been: was, have, be, tatars, were, that, circ, agave,
# Nearest to three: four, five, six, two, eight, seven, zero, one,
# Nearest to these: they, circ, other, cebus, which, some, many, and,
# Nearest to this: it, which, that, the, a, an, circ, but,
# Nearest to about: four, three, cebus, five, two, deism, zero, six,
# Nearest to its: their, the, agouti, truetype, microcebus, ursus, cebus, thaler,
# Nearest to they: these, it, that, to, not, circ, but, he,
# Nearest to may: can, circ, but, to, heh, would, or, not,
# Nearest to there: that, it, not, which, however, but, only, this,
# Average loss at step  72000 :  5.14197527205944
# Average loss at step  74000 :  5.17067057967186
# Average loss at step  76000 :  5.133512539029121
# Average loss at step  78000 :  5.204014168918133
# Average loss at step  80000 :  5.197991533637047
# Nearest to which: that, circ, it, this, and, ursus, cebus, capuchin,
# Nearest to has: have, had, is, was, by, ursus, thaler, escuela,
# Nearest to people: and, abet, concerned, zero, agouti, aveiro, were, circ,
# Nearest to eight: seven, nine, six, five, four, three, zero, two,
# Nearest to the: ursus, a, circ, cebus, microcebus, one, agouti, its,
# Nearest to if: that, but, acapulco, agouti, can, proportional, it, which,
# Nearest to history: agouti, ursus, abet, of, release, see, circ, thaler,
# Nearest to been: was, be, have, were, tatars, agave, circ, mcduck,
# Nearest to three: four, six, five, seven, eight, two, one, zero,
# Nearest to these: they, circ, other, and, some, many, cebus, which,
# Nearest to this: it, which, that, an, a, the, circ, but,
# Nearest to about: four, two, zero, cebus, three, that, five, six,
# Nearest to its: their, the, microcebus, iit, agouti, truetype, ursus, a,
# Nearest to they: these, to, it, he, circ, not, dasyprocta, but,
# Nearest to may: can, would, circ, but, to, or, heh, three,
# Nearest to there: that, it, which, but, however, only, these, not,
# Average loss at step  82000 :  5.153378495931626
# Average loss at step  84000 :  5.1735508903265
# Average loss at step  86000 :  5.16283220410347
# Average loss at step  88000 :  5.1264330527782445
# Average loss at step  90000 :  5.123444931864738
# Nearest to which: that, circ, this, ursus, cebus, agouti, capuchin, it,
# Nearest to has: have, had, was, is, by, ursus, thaler, escuela,
# Nearest to people: and, abet, agouti, concerned, their, circ, aveiro, zero,
# Nearest to eight: seven, six, nine, five, four, three, one, zero,
# Nearest to the: a, circ, this, agouti, ursus, its, cebus, microcebus,
# Nearest to if: that, acapulco, but, not, agouti, can, proportional, which,
# Nearest to history: agouti, ursus, the, abet, list, release, see, circ,
# Nearest to been: have, was, be, were, tatars, agave, circ, mcduck,
# Nearest to three: four, five, six, seven, two, eight, zero, one,
# Nearest to these: they, some, other, circ, many, which, all, and,
# Nearest to this: it, which, the, that, a, an, circ, but,
# Nearest to about: two, three, zero, cebus, five, six, that, which,
# Nearest to its: their, the, iit, microcebus, agouti, ursus, a, truetype,
# Nearest to they: these, to, he, not, but, circ, which, it,
# Nearest to may: can, would, dreidel, circ, but, will, or, heh,
# Nearest to there: that, but, which, however, these, it, in, only,
# Average loss at step  92000 :  5.067228707671165
# Average loss at step  94000 :  5.130913824558258
# Average loss at step  96000 :  5.090817713499069
# Average loss at step  98000 :  5.012017986655235
# Average loss at step  100000 :  5.104234972476959
# Nearest to which: that, this, circ, ursus, cebus, and, it, but,
# Nearest to has: have, had, is, was, by, but, thaler, escuela,
# Nearest to people: and, zero, abet, agouti, aveiro, concerned, their, circ,
# Nearest to eight: seven, six, nine, four, three, five, zero, two,
# Nearest to the: a, its, cebus, this, agouti, ursus, circ, upanija,
# Nearest to if: that, acapulco, not, but, agouti, when, proportional, which,
# Nearest to history: agouti, ursus, abet, see, list, circ, altenberg, thaler,
# Nearest to been: was, be, have, were, that, tatars, circ, agave,
# Nearest to three: four, five, six, seven, eight, two, zero, nine,
# Nearest to these: they, some, other, many, which, circ, all, and,
# Nearest to this: it, which, that, the, a, an, ursus, circ,
# Nearest to about: zero, two, three, five, cebus, that, circ, agouti,
# Nearest to its: the, their, microcebus, iit, agouti, ursus, truetype, this,
# Nearest to they: these, not, he, but, it, which, to, their,
# Nearest to may: can, would, will, circ, dreidel, or, but, heh,
# Nearest to there: that, but, which, however, it, endo, only, these,

# %%
# Larger skip_window
batch_size = 128
embedding_size = 128  # Dimension of the embedding vector.
skip_window = 1  # How many words to consider left and right.
num_skips = 2  # How many times to reuse an input to generate a label.
num_sampled = 64  # Number of negative examples to sample.
vocabulary_size = 500
main()
# Out:
# Found and verified text8.zip
# Data size 17005207
# Most common words (+UNK) [['UNK', 6747638], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [0, 0, 12, 6, 195, 2, 0, 46, 59, 156] ['UNK', 'UNK', 'as', 'a', 'term', 'of', 'UNK', 'first', 'used', 'against']
# 0 UNK -> 0 UNK
# 0 UNK -> 12 as
# 12 as -> 6 a
# 12 as -> 0 UNK
# 6 a -> 12 as
# 6 a -> 195 term
# 195 term -> 6 a
# 195 term -> 2 of
# Initialized
# Average loss at step  0 :  132.08914184570312
# Nearest to six: days, religious, control, second, head, began, university, single,
# Nearest to from: council, jewish, days, many, there, order, possible, him,
# Nearest to during: born, original, james, m, history, forces, family, some,
# Nearest to states: used, members, through, george, hand, children, article, began,
# Nearest to had: french, important, ancient, g, who, used, him, science,
# Nearest to that: english, city, century, v, groups, than, james, life,
# Nearest to this: because, never, she, john, especially, nine, council, however,
# Nearest to be: various, important, when, major, following, non, company, side,
# Nearest to but: century, you, is, forms, y, new, known, external,
# Nearest to years: death, head, above, been, public, both, systems, among,
# Nearest to its: ancient, released, actor, jewish, black, largest, almost, often,
# Nearest to s: main, n, area, have, set, early, it, human,
# Nearest to the: include, though, john, form, north, god, language, population,
# Nearest to will: again, ii, government, free, it, source, play, should,
# Nearest to used: states, day, christian, references, had, some, current, upon,
# Nearest to would: northern, him, second, full, process, change, chinese, jewish,
# Average loss at step  2000 :  4.784613499760628
# Average loss at step  4000 :  3.7761316686868667
# Average loss at step  6000 :  3.766742689847946
# Average loss at step  8000 :  3.7261295603513718
# Average loss at step  10000 :  3.688467792868614
# Nearest to six: zero, days, eight, religious, nine, one, five, th,
# Nearest to from: council, jewish, to, political, days, certain, five, in,
# Nearest to during: original, born, m, james, through, forces, family, by,
# Nearest to states: used, UNK, members, hand, george, article, children, began,
# Nearest to had: french, ancient, important, used, is, science, upon, g,
# Nearest to that: english, city, than, current, life, groups, century, sometimes,
# Nearest to this: because, never, the, john, she, especially, class, however,
# Nearest to be: various, is, important, non, led, against, have, almost,
# Nearest to but: century, you, is, forms, known, new, external, will,
# Nearest to years: death, systems, head, UNK, year, above, public, both,
# Nearest to its: the, released, ancient, jewish, almost, black, actor, largest,
# Nearest to s: main, the, n, it, human, james, set, have,
# Nearest to the: UNK, a, his, its, culture, language, their, this,
# Nearest to will: again, ii, should, could, free, but, period, if,
# Nearest to used: UNK, states, day, christian, had, current, some, party,
# Nearest to would: northern, could, him, d, chinese, UNK, second, full,
# Average loss at step  12000 :  3.736154079556465
# Average loss at step  14000 :  3.6938110107183455
# Average loss at step  16000 :  3.650294426202774
# Average loss at step  18000 :  3.668549144208431
# Average loss at step  20000 :  3.6705367003679275
# Nearest to six: nine, zero, eight, one, five, days, four, three,
# Nearest to from: in, to, of, jewish, political, council, by, five,
# Nearest to during: original, m, james, by, through, born, of, forces,
# Nearest to states: used, hand, members, UNK, u, began, article, modern,
# Nearest to had: french, is, important, ancient, who, science, used, upon,
# Nearest to that: UNK, city, current, english, sometimes, life, type, than,
# Nearest to this: the, never, because, UNK, she, class, especially, which,
# Nearest to be: UNK, is, have, various, important, against, non, led,
# Nearest to but: century, you, is, forms, known, to, term, new,
# Nearest to years: death, systems, head, one, year, public, three, above,
# Nearest to its: the, released, ancient, his, every, black, almost, jewish,
# Nearest to s: main, n, human, the, it, set, of, james,
# Nearest to the: a, his, one, their, its, this, UNK, nine,
# Nearest to will: again, should, ii, could, UNK, can, free, are,
# Nearest to used: UNK, states, christian, day, had, less, current, some,
# Nearest to would: could, northern, him, may, is, d, if, chinese,
# Average loss at step  22000 :  3.7330215977430345
# Average loss at step  24000 :  3.681305432200432
# Average loss at step  26000 :  3.6623254693746565
# Average loss at step  28000 :  3.6628434623479844
# Average loss at step  30000 :  3.6760846378803254
# Nearest to six: nine, eight, zero, five, four, three, seven, two,
# Nearest to from: in, of, to, jewish, by, political, council, five,
# Nearest to during: original, by, through, of, after, james, in, second,
# Nearest to states: UNK, used, six, hand, members, modern, began, european,
# Nearest to had: french, is, have, science, upon, has, was, g,
# Nearest to that: english, sometimes, city, last, around, others, late, type,
# Nearest to this: the, because, never, which, she, especially, class, it,
# Nearest to be: is, have, various, important, non, been, against, by,
# Nearest to but: century, you, forms, which, known, found, term, external,
# Nearest to years: death, two, systems, three, head, year, public, water,
# Nearest to its: the, released, his, ancient, every, black, jewish, al,
# Nearest to s: main, the, n, and, zero, human, of, two,
# Nearest to the: UNK, a, its, his, their, nine, an, this,
# Nearest to will: again, should, ii, could, can, are, may, free,
# Nearest to used: UNK, states, day, christian, less, make, had, current,
# Nearest to would: could, northern, may, can, him, d, if, chinese,
# Average loss at step  32000 :  3.6867449852228167
# Average loss at step  34000 :  3.712411571741104
# Average loss at step  36000 :  3.68000804233551
# Average loss at step  38000 :  3.6683171876072884
# Average loss at step  40000 :  3.6456450340747835
# Nearest to six: eight, nine, zero, five, four, three, seven, two,
# Nearest to from: in, of, by, to, jewish, among, into, for,
# Nearest to during: in, original, by, of, through, after, forces, second,
# Nearest to states: used, hand, members, UNK, modern, u, six, european,
# Nearest to had: have, french, has, is, science, was, upon, who,
# Nearest to that: UNK, which, sometimes, around, this, last, who, others,
# Nearest to this: which, because, the, never, she, a, it, class,
# Nearest to be: is, have, been, various, and, by, make, important,
# Nearest to but: century, you, which, term, forms, and, known, just,
# Nearest to years: death, one, three, two, systems, head, year, seven,
# Nearest to its: the, his, released, their, ancient, every, black, al,
# Nearest to s: main, n, the, james, two, references, zero, of,
# Nearest to the: his, a, its, their, one, nine, eight, three,
# Nearest to will: should, again, could, can, ii, may, are, free,
# Nearest to used: states, less, day, UNK, christian, seen, make, home,
# Nearest to would: could, can, may, northern, is, him, had, to,
# Average loss at step  42000 :  3.702899040699005
# Average loss at step  44000 :  3.695332542181015
# Average loss at step  46000 :  3.703143023133278
# Average loss at step  48000 :  3.6822713042497637
# Average loss at step  50000 :  3.7082355909347533
# Nearest to six: eight, nine, four, three, five, seven, zero, two,
# Nearest to from: in, of, by, to, for, into, jewish, among,
# Nearest to during: in, original, by, through, of, after, second, with,
# Nearest to states: used, hand, members, modern, six, eight, european, u,
# Nearest to had: have, has, was, who, french, upon, three, is,
# Nearest to that: which, UNK, around, last, sometimes, as, this, who,
# Nearest to this: the, which, it, because, never, some, she, a,
# Nearest to be: is, have, by, been, various, was, and, make,
# Nearest to but: century, and, you, which, forms, found, though, known,
# Nearest to years: death, three, seven, two, systems, year, head, time,
# Nearest to its: the, his, their, black, released, every, ancient, jewish,
# Nearest to s: main, the, of, zero, four, and, six, two,
# Nearest to the: his, a, their, its, this, eight, nine, three,
# Nearest to will: should, could, can, again, ii, may, to, are,
# Nearest to used: states, seen, less, day, christian, make, does, UNK,
# Nearest to would: could, can, may, to, northern, him, had, is,
# Average loss at step  52000 :  3.667002161026001
# Average loss at step  54000 :  3.66427184677124
# Average loss at step  56000 :  3.6852863247394563
# Average loss at step  58000 :  3.6811771025657656
# Average loss at step  60000 :  3.7068789633512496
# Nearest to six: eight, nine, five, four, seven, three, zero, two,
# Nearest to from: in, of, by, to, for, into, jewish, at,
# Nearest to during: in, original, by, through, of, after, second, with,
# Nearest to states: used, hand, members, modern, eight, council, UNK, countries,
# Nearest to had: has, have, was, upon, would, science, french, who,
# Nearest to that: which, who, as, sometimes, this, around, last, where,
# Nearest to this: which, it, the, because, she, some, council, that,
# Nearest to be: have, is, been, was, make, were, various, are,
# Nearest to but: which, you, century, found, known, forms, that, term,
# Nearest to years: three, death, two, systems, seven, year, eight, four,
# Nearest to its: the, his, their, black, ancient, every, released, jewish,
# Nearest to s: zero, main, two, of, the, isbn, and, his,
# Nearest to the: a, his, its, their, UNK, eight, one, an,
# Nearest to will: should, can, could, again, ii, may, are, to,
# Nearest to used: seen, states, less, written, called, day, christian, does,
# Nearest to would: could, can, may, to, northern, had, him, if,
# Average loss at step  62000 :  3.6849820405244826
# Average loss at step  64000 :  3.6662022058367727
# Average loss at step  66000 :  3.6257238222360613
# Average loss at step  68000 :  3.668891701340675
# Average loss at step  70000 :  3.694791626930237
# Nearest to six: eight, five, three, four, nine, seven, zero, two,
# Nearest to from: in, of, by, to, for, into, with, against,
# Nearest to during: in, of, original, by, through, after, second, with,
# Nearest to states: members, hand, countries, used, european, modern, council, league,
# Nearest to had: has, have, was, upon, would, who, never, is,
# Nearest to that: which, this, as, around, who, last, where, sometimes,
# Nearest to this: which, it, the, that, some, she, because, never,
# Nearest to be: have, is, was, been, make, are, by, were,
# Nearest to but: which, you, found, and, though, however, century, known,
# Nearest to years: death, three, year, eight, two, four, time, systems,
# Nearest to its: the, his, their, ancient, black, every, jewish, several,
# Nearest to s: of, two, main, zero, isbn, his, and, the,
# Nearest to the: a, his, its, their, nine, any, this, an,
# Nearest to will: should, can, could, again, may, ii, must, are,
# Nearest to used: seen, less, called, written, states, home, known, day,
# Nearest to would: could, can, may, to, had, must, is, was,
# Average loss at step  72000 :  3.674541650056839
# Average loss at step  74000 :  3.6524169934391977
# Average loss at step  76000 :  3.7096393039226534
# Average loss at step  78000 :  3.6517903416156767
# Average loss at step  80000 :  3.585035636842251
# Nearest to six: eight, seven, five, four, nine, three, two, zero,
# Nearest to from: of, in, by, into, for, to, with, among,
# Nearest to during: in, by, original, of, through, after, second, with,
# Nearest to states: members, countries, hand, european, used, nine, modern, league,
# Nearest to had: have, has, was, upon, would, who, never, are,
# Nearest to that: which, UNK, this, last, as, around, generally, who,
# Nearest to this: which, it, the, some, that, she, because, a,
# Nearest to be: have, is, was, been, and, are, make, by,
# Nearest to but: and, which, you, however, found, though, term, that,
# Nearest to years: death, two, year, three, seven, UNK, books, eight,
# Nearest to its: the, his, their, every, black, a, ancient, several,
# Nearest to s: zero, five, isbn, four, his, two, main, james,
# Nearest to the: a, his, their, its, UNK, this, an, six,
# Nearest to will: can, should, could, again, may, ii, must, would,
# Nearest to used: seen, written, called, less, known, states, given, possible,
# Nearest to would: could, can, may, was, must, had, is, should,
# Average loss at step  82000 :  3.6780707408189772
# Average loss at step  84000 :  3.657845699548721
# Average loss at step  86000 :  3.669809890985489
# Average loss at step  88000 :  3.659167594075203
# Average loss at step  90000 :  3.689367297410965
# Nearest to six: seven, eight, five, three, nine, four, zero, two,
# Nearest to from: of, in, by, into, for, with, at, on,
# Nearest to during: in, of, by, after, original, through, second, with,
# Nearest to states: countries, european, members, hand, council, modern, used, church,
# Nearest to had: has, have, was, upon, never, would, UNK, who,
# Nearest to that: which, UNK, as, in, around, last, this, who,
# Nearest to this: it, which, the, some, one, a, that, because,
# Nearest to be: have, is, was, been, are, take, make, become,
# Nearest to but: and, which, you, however, found, that, though, UNK,
# Nearest to years: two, year, death, seven, eight, three, days, books,
# Nearest to its: the, their, his, every, some, black, a, several,
# Nearest to s: of, and, isbn, his, two, zero, six, main,
# Nearest to the: a, his, their, UNK, its, this, any, some,
# Nearest to will: can, could, should, may, again, ii, must, would,
# Nearest to used: seen, UNK, written, called, known, considered, possible, given,
# Nearest to would: could, can, may, was, must, will, to, should,
# Average loss at step  92000 :  3.7001435695886613
# Average loss at step  94000 :  3.6656099350452425
# Average loss at step  96000 :  3.6813407850265505
# Average loss at step  98000 :  3.641328651547432
# Average loss at step  100000 :  3.6601820724010468
# Nearest to six: seven, eight, three, five, nine, four, zero, two,
# Nearest to from: in, of, by, into, for, with, at, to,
# Nearest to during: in, after, by, original, through, of, with, second,
# Nearest to states: countries, UNK, european, members, council, modern, others, church,
# Nearest to had: has, have, was, upon, never, would, is, who,
# Nearest to that: which, this, as, but, itself, often, because, where,
# Nearest to this: it, which, the, some, that, because, never, a,
# Nearest to be: have, is, was, been, by, make, become, are,
# Nearest to but: and, which, however, that, though, you, found, term,
# Nearest to years: death, two, year, days, three, seven, six, books,
# Nearest to its: the, their, his, some, every, black, several, a,
# Nearest to s: and, two, isbn, four, his, the, of, five,
# Nearest to the: a, his, their, its, any, an, this, nine,
# Nearest to will: can, could, should, may, again, ii, must, would,
# Nearest to used: seen, written, known, UNK, called, considered, possible, given,
# Nearest to would: could, can, may, must, will, should, was, had,
